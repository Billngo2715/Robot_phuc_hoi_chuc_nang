# %% [markdown]
# ## Import thư viện

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import spatialmath.base.symbolic as sym
from roboticstoolbox import DHRobot, RevoluteDH, ERobot, ELink, ETS
from math import pi, sin, cos
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from DMP.dmp_discrete import DMPs_discrete
from spatialmath import *
from math import sqrt
# %matplotlib notebook

# %% [markdown]
# ## Khởi tạo robot từ bảng DH

# %%
# canh tay do (DH mới)
L1 = RevoluteDH(a=0, d=125.5, alpha=pi/2)
L2 = RevoluteDH(a=0, d=0, alpha=-pi/2)
L3 = RevoluteDH(a=0, d=340, alpha=-pi/2)
L4 = RevoluteDH(a=0, d=0, alpha=pi/2)
L5 = RevoluteDH(a=0, d=270, alpha=pi/2)

robot = DHRobot([L1, L2, L3, L4, L5],name='Huy',gravity=[0,0,9.81])

# %% [markdown]
# ## Hàm gen dmp

# %%
def dmp_gen(q_ik, q_qd, robot, random_e, n):
    """"
    q_ik: 
    q_qd: quỹ đạo mẫu
    robot
    ramdom_e: giá trị random góc khớp (rad)
    n: số lượng quỹ đạo mỗi điểm
    """
    
#     i = np.random.choice(range(len(paths)))
    i=3
    q_do = np.loadtxt(folder + paths[i], dtype = np.float64)*pi/180
    q_do[:,1] = pi/2- q_do[:,1] 
    q_qd= q_do
    E_do = robot.fkine(q_do).t
    q_dmps=[]
    E_q_dmps=[]
    T=robot.fkine(q_qd)
    E_do=T.t
    dmp_q=DMPs_discrete(n_dmps=5,n_bfs=100, dt=1/50)
    # dmp cho q
    dmp_q.imitate_path(y_des=q_qd.T)
    for q in tqdm(q_ik):
        for i in tqdm(range(n)):
            # omega_q = dmp_q.w
            dmp_q.y0=q_qd[0,:]+np.random.rand(5)*random_e/5
#             Te=robot.fkine(q[-1,:])
            dmp_q.goal=q+np.random.rand(5)*random_e
            q_track, dq_track, ddq_track = dmp_q.rollout()
            q_dmp = np.array(q_track)
            E_q_dmp=robot.fkine(q_dmp).t

            q_dmps.append(q_dmp)
            E_q_dmps.append(E_q_dmp)
    return  np.array(q_dmps), np.array(E_q_dmps)

# %% [markdown]
# ## Hàm show đồ thị điểm cuối 3D

# %%
fig = plt.figure(figsize = (8,6),dpi =100)
ax = fig.add_subplot(111, projection='3d')
plt.rcdefaults() 
plt.title('Reaching the cup task', weight='bold')
ax.set_facecolor("white")
ax.set_xlabel('X (mm)')
ax.set_ylabel('Y (mm)')
ax.set_zlabel('Z (mm)')


def plotE(E, color='k'):
    ax.scatter3D(E[:, 0], E[:, 1], E[:, 2], color=color)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Lưu ảnh đồ thị

# %%
# plt.savefig("plot/4000_5000_enpoint.svg")

# %% [markdown]
# ### Load điểm cuối (goal)

# %%
q_ik = np.loadtxt('data/diem_cuoi/q_441.txt',  delimiter=',')
E_ik = np.loadtxt('data/diem_cuoi/E_441.txt',  delimiter=',')
plotE(E_ik, color='k')

# %% [markdown]
# ### Lấy 25 điểm

# %%
##
q_ik_25= []
E_ik_25= []

for i in range(21):
    for j in range(21):
        if (i%5==0)&(j%5==0):
#             print(i,j)
            q_ik_25.append(q_ik[5*i+j])
            E_ik_25.append(E_ik[5*i+j])
            
q_ik_25 = np.array(q_ik_25)
E_ik_25 = np.array(E_ik_25)
print(q_ik_25.shape)
plotE(E_ik_25, color='r')
# Out:
# (25, 5)

# %% [markdown]
# ## Load quỹ đạo đo được

# %%
folder = 'data/dong_tac/lay_nuoc_cu/'
paths = os.listdir(folder)

for i in range(len(paths)):
    q_do = np.loadtxt(folder + paths[i], dtype = np.float64)*pi/180
    q_do[:,1] = pi/2- q_do[:,1] 
    E_do = robot.fkine(q_do).t
    plotE(E_do, color='b')

# %%
E_do
# Out:
# array([[-4.59201525e+02,  1.60600215e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.59201525e+02,  1.60600215e+02,  4.07784498e+02],
#        [-4.59201525e+02,  1.60600215e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.58262213e+02,  1.63261184e+02,  4.07784498e+02],
#        [-4.56086827e+02,  1.65473800e+02,  4.08660184e+02],
#        [-4.52712229e+02,  1.64249455e+02,  4.09298413e+02],
#        [-4.49897855e+02,  1.66108429e+02,  4.07088847e+02],
#        [-4.48935483e+02,  1.65752139e+02,  4.05969836e+02],
#        [-4.50585190e+02,  1.66764350e+02,  4.01236608e+02],
#        [-4.45497250e+02,  1.68158319e+02,  4.05655025e+02],
#        [-4.35584559e+02,  1.67513100e+02,  4.11136871e+02],
#        [-4.19809168e+02,  1.67114727e+02,  4.24137261e+02],
#        [-4.08298242e+02,  1.65315138e+02,  4.36428003e+02],
#        [-3.97081976e+02,  1.60715674e+02,  4.50204319e+02],
#        [-3.86795599e+02,  1.51292148e+02,  4.65416397e+02],
#        [-3.73277066e+02,  1.38599322e+02,  4.82853223e+02],
#        [-3.60811505e+02,  1.31353946e+02,  4.96855488e+02],
#        [-3.43611763e+02,  1.22505212e+02,  5.14551027e+02],
#        [-3.28385051e+02,  1.07864370e+02,  5.29410013e+02],
#        [-3.16002621e+02,  9.34995422e+01,  5.39332705e+02],
#        [-3.02220131e+02,  8.24064192e+01,  5.48518203e+02],
#        [-2.89820082e+02,  7.40804161e+01,  5.55356623e+02],
#        [-2.75247153e+02,  6.49675569e+01,  5.65199220e+02],
#        [-2.60953805e+02,  4.93703855e+01,  5.73705406e+02],
#        [-2.49867470e+02,  3.34040404e+01,  5.81430726e+02],
#        [-2.33933561e+02,  1.73442666e+01,  5.91703253e+02],
#        [-2.15651272e+02,  3.56054477e-01,  6.00753205e+02],
#        [-2.04261231e+02, -9.60902709e+00,  6.07625835e+02],
#        [-1.94188230e+02, -1.62583328e+01,  6.13520957e+02],
#        [-1.86481892e+02, -2.35173694e+01,  6.19061983e+02],
#        [-1.79727661e+02, -3.38079667e+01,  6.24669062e+02],
#        [-1.73327172e+02, -4.38350439e+01,  6.29764857e+02],
#        [-1.61023528e+02, -5.31703390e+01,  6.37317459e+02],
#        [-1.51857098e+02, -5.81581274e+01,  6.42975434e+02],
#        [-1.45179316e+02, -6.20867504e+01,  6.46101809e+02],
#        [-1.47028954e+02, -6.39446061e+01,  6.47008798e+02],
#        [-1.48740203e+02, -6.55855733e+01,  6.47953685e+02],
#        [-1.49770562e+02, -6.59616089e+01,  6.48422353e+02],
#        [-1.49770562e+02, -6.59616089e+01,  6.48422353e+02],
#        [-1.49770562e+02, -6.59616089e+01,  6.48422353e+02]])

# %%
 q_dmps, E_q_dmp= dmp_gen(q_ik_25,q_do, robot, random_e=0.25, n=200)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plotE(E_q_dmp[4000:,-1,:], color='k')

# %% [markdown]
# ## Lưu kết quả

# %%
np.save('q_dmps_db1_gen_25.npy',q_dmps)
np.save('E_q_dmps_db1_gen_25.npy',E_q_dmp)
